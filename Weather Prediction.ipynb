# %% [markdown]
# # Weather Prediction

# %%
import pandas as pd

# %%
df = pd.read_csv("seattle-weather.csv")

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind weather
# 0  20-08-2023           4.17      35.0      26.7  10.4    rain
# 1  21-08-2023           0.00      35.0      28.3  10.4    rain
# 2  22-08-2023           8.33      33.6      27.0  10.0    rain
# 3  23-08-2023           8.33      34.0      25.0  15.0    rain
# 4  24-08-2023          12.50      34.0      24.0  45.2    rain

# %%
df.isna().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
X = df.drop(columns=['date', 'weather'])
y = df['weather']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X_test)

# %%
X_test
# Out:
#      precipitation  temp_max  temp_min  wind
# 165           0.00      31.0      25.0   9.2
# 33            0.00      34.0      27.8  11.4
# 15            4.17      31.0      26.0  11.3
# 312           0.00      33.4      29.8  16.1
# 57           12.50      32.2      26.0  11.4
# ..             ...       ...       ...   ...
# 234           0.00      34.0      27.5  11.4
# 363           8.33      33.0      29.0  12.8
# 210           0.00      32.3      26.8   6.9
# 262           4.17      35.0      26.0  10.3
# 301           4.17      38.0      29.0  16.1
#
# [111 rows x 4 columns]

# %%
predictions
# Out:
# array(['rain', 'sun', 'rain', 'rain', 'rain', 'sun', 'rain', 'rain',
#        'rain', 'rain', 'sun', 'rain', 'sun', 'rain', 'rain', 'sun',
#        'rain', 'sun', 'sun', 'rain', 'rain', 'sun', 'rain', 'sun', 'sun',
#        'sun', 'sun', 'sun', 'sun', 'rain', 'rain', 'sun', 'rain', 'rain',
#        'sun', 'rain', 'rain', 'sun', 'rain', 'rain', 'sun', 'sun', 'rain',
#        'rain', 'rain', 'rain', 'rain', 'rain', 'sun', 'sun', 'sun',
#        'rain', 'sun', 'rain', 'sun', 'sun', 'rain', 'rain', 'sun', 'rain',
#        'sun', 'sun', 'rain', 'rain', 'rain', 'rain', 'sun', 'rain', 'sun',
#        'rain', 'rain', 'sun', 'rain', 'rain', 'rain', 'sun', 'rain',
#        'rain', 'rain', 'rain', 'sun', 'rain', 'rain', 'rain', 'rain',
#        'rain', 'rain', 'sun', 'sun', 'rain', 'rain', 'sun', 'sun', 'rain',
#        'sun', 'sun', 'rain', 'sun', 'rain', 'rain', 'sun', 'rain', 'rain',
#        'sun', 'rain', 'rain', 'sun', 'rain', 'sun', 'rain', 'rain'],
#       dtype=object)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#         rain       0.94      0.82      0.88        77
#          sun       0.68      0.88      0.77        34
#
#     accuracy                           0.84       111
#    macro avg       0.81      0.85      0.82       111
# weighted avg       0.86      0.84      0.84       111

# %%
test_weather = {
    'precipitation': 4.17	,
    'temp_max': 35.0	,
    'temp_min': 10,
    'wind': 6.5
}

test_df = pd.DataFrame([test_weather])
test_df
# Out:
#    precipitation  temp_max  temp_min  wind
# 0            0.0        50        10   6.5

# %%
model.predict(test_df)
# Out:
# array(['sun'], dtype=object)
